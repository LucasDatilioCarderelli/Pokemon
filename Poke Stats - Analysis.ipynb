# %% [markdown]
# # POKÉ STATS ANALISYS

# %% [markdown]
# #### - Importando o Pandas e Lendo

# %%
import pandas as pd

pokemons = pd.read_csv(r'C:\Users\lluca\Documents\Pokemon.csv')

# %%
pokemons.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
pokemons.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %% [markdown]
# #### - Comando loc e iloc

# %%
# pokemons.loc[4:7, 'Name':'Type 2']

# %%
# pokemons.iloc[9:13, 1:5]

# %% [markdown]
# #### - Filtrando

# %%
elementos1 = pd.unique(pokemons['Type 1'])
# elementos1

# %%
elementos2 = pd.unique(pokemons['Type 2'])
# elementos2

# %%
# pokemons.sort_values('Type 1').head()

# %%
# pokemons.sort_values('HP', ascending = False).head(3)

# %%
# pokemons.sort_values('HP', ascending = True).head(3)

# %%
# pokemons.iloc[314:317, 0:]

# %%
# pokemons.sort_values('Total').head(3)

# %%
best_pokemon = pokemons['Name'][0]
print(f'O {best_pokemon} é o melhor!')
# Out:
# O Bulbasaur é o melhor!

# %% [markdown]
# ##### - Printando os Lendarios

# %%
# Lendarios = []
# print("ID | Name")
# for i, n in enumerate(pokemons['Legendary']):
    # if n == True:
        # Lendarios.append(pokemons['Name'][i])
        # print(f"{i}: {pokemons['Name'][i]}")
# pokemons[(pokemons['Legendary'] == True) & (pokemons['Generation'] == 1)][['#', 'Name']]

# %%
# pokemons[(pokemons['Type 1'] == 'Grass') & ((pokemons['Attack'] >= 100) | (pokemons['Defense'] >= 100))].head()

# %%
pokemons[['Type 1', 'Legendary', 'HP', 'Total']].groupby(['Type 1', 'Legendary']).mean()
# Out:
#                             HP       Total
# Type 1   Legendary
# Bug      False       56.884058  378.927536
# Dark     False       64.655172  432.344828
#          True        98.000000  640.000000
# Dragon   False       72.650000  476.850000
#          True       101.083333  673.333333
# Electric False       57.325000  429.750000
#          True        84.500000  580.000000
# Fairy    False       70.875000  396.500000
#          True       126.000000  680.000000
# Fighting False       69.851852  416.444444
# Fire     False       67.085106  442.127660
#          True        96.400000  608.000000
# Flying   False       62.500000  390.000000
#          True        79.000000  580.000000
# Ghost    False       58.733333  423.533333
#          True       150.000000  680.000000
# Grass    False       65.940299  413.432836
#          True        97.000000  593.333333
# Ground   False       70.821429  405.714286
#          True        94.500000  660.000000
# ...

# %%
pokemons[['Type 1', 'Total']].groupby(['Type 1']).mean().sort_values('Total', ascending = False)
# Out:
#                Total
# Type 1
# Dragon    550.531250
# Steel     487.703704
# Flying    485.000000
# Psychic   475.947368
# Fire      458.076923
# Rock      453.750000
# Dark      445.741935
# Electric  443.409091
# Ghost     439.562500
# Ground    437.500000
# Ice       433.458333
# Water     430.455357
# Grass     421.142857
# Fighting  416.444444
# Fairy     413.176471
# Normal    401.683673
# Poison    399.142857
# Bug       378.927536

# %% [markdown]
# #### - Graficos

# %%
# pokemons['HP'].plot()

# %%
import seaborn as sns

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (9,5)

# pokemons['HP'].value_counts()
# pokeHPmult10 = round(pokemons['HP'], -1).value_counts()

# pokemons['HP'].hist()
bins = [10,30,50,70,90,110,130,150,170,190,210,230,250]

plt.hist(pokemons['HP'], bins=bins)
# sns.distplot(pokemons.HP, bins=bins)
plt.title('Distribuição por Hp')
plt.xlabel('Hp')
plt.ylabel('Un')

plt.xticks(bins)

plt.show()

# %%
# 'Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 
# 'Electric','Ground', 'Fairy', 'Fighting', 'Psychic', 
# 'Rock', 'Ghost', 'Ice', 'Dragon', 'Dark', 'Steel', 'Flying'
Grama = pokemons.loc[pokemons['Type 1'] == 'Grass']['Total']
Fogo = pokemons.loc[pokemons['Type 1'] == 'Fire']['Total']
Agua = pokemons.loc[pokemons['Type 1'] == 'Water']['Total']
Inseto = pokemons.loc[pokemons['Type 1'] == 'Bug']['Total']
Normal = pokemons.loc[pokemons['Type 1'] == 'Normal']['Total']
Veneno = pokemons.loc[pokemons['Type 1'] == 'Poison']['Total']
Eletrico = pokemons.loc[pokemons['Type 1'] == 'Electric']['Total']
Terrestre = pokemons.loc[pokemons['Type 1'] == 'Ground']['Total']
Fada = pokemons.loc[pokemons['Type 1'] == 'Fairy']['Total']
Lutador = pokemons.loc[pokemons['Type 1'] == 'Fighting']['Total']
Pisiquico = pokemons.loc[pokemons['Type 1'] == 'Psychic']['Total']
Pedra = pokemons.loc[pokemons['Type 1'] == 'Rock']['Total']
Fantasma = pokemons.loc[pokemons['Type 1'] == 'Ghost']['Total']
Gelo = pokemons.loc[pokemons['Type 1'] == 'Ice']['Total']
Dragao = pokemons.loc[pokemons['Type 1'] == 'Dragon']['Total']
Sombrio = pokemons.loc[pokemons['Type 1'] == 'Dark']['Total']
Aço = pokemons.loc[pokemons['Type 1'] == 'Steel']['Total']
Voador = pokemons.loc[pokemons['Type 1'] == 'Flying']['Total']

labels = ['Dragao','Aço','Voador','Pisiquico','Fogo','Pedra',
          'Sombrio','Eletrico','Fantasma','Terrestre','Gelo','Agua',
          'Grama','Lutador','Fada','Normal','Veneno','Inseto']

plt.boxplot([Dragao,Aço,Voador,Pisiquico,Fogo,Pedra,
             Sombrio,Eletrico,Fantasma,Terrestre,Gelo,Agua,
             Grama,Lutador,Fada,Normal,Veneno,Inseto], labels=labels)

plt.title('Status por Tipo')
plt.xticks(rotation=45)
plt.ylabel('Stats Total')

plt.show()

# %%
Dragon = pokemons.loc[(pokemons['Type 1'] == 'Dragon')].count()[0]
Steel = pokemons.loc[(pokemons['Type 1'] == 'Steel')].count()[0]
Flying = pokemons.loc[(pokemons['Type 1'] == 'Flying')].count()[0]
Psychic = pokemons.loc[(pokemons['Type 1'] == 'Psychic')].count()[0]
Fire = pokemons.loc[(pokemons['Type 1'] == 'Fire')].count()[0]
Rock = pokemons.loc[(pokemons['Type 1'] == 'Rock')].count()[0]
Dark = pokemons.loc[(pokemons['Type 1'] == 'Dark')].count()[0]
Electric = pokemons.loc[(pokemons['Type 1'] == 'Electric')].count()[0]
Ghost = pokemons.loc[(pokemons['Type 1'] == 'Ghost')].count()[0]
Ground = pokemons.loc[(pokemons['Type 1'] == 'Ground')].count()[0]
Ice = pokemons.loc[(pokemons['Type 1'] == 'Ice')].count()[0]
Water = pokemons.loc[(pokemons['Type 1'] == 'Water')].count()[0]
Grass = pokemons.loc[(pokemons['Type 1'] == 'Grass')].count()[0]
Fighting = pokemons.loc[(pokemons['Type 1'] == 'Fighting')].count()[0]
Fairy = pokemons.loc[(pokemons['Type 1'] == 'Fairy')].count()[0]
Normal = pokemons.loc[(pokemons['Type 1'] == 'Normal')].count()[0]
Poison = pokemons.loc[(pokemons['Type 1'] == 'Poison')].count()[0]
Bug = pokemons.loc[(pokemons['Type 1'] == 'Bug')].count()[0]

x = ['Dragao','Aço','Voador','Pisiquico','Fogo','Pedra',
          'Sombrio','Eletrico','Fantasma','Terrestre','Gelo','Agua',
          'Grama','Lutador','Fada','Normal','Veneno','Inseto']
y = [Dragon,Steel,Flying,Psychic,Fire,Rock,Dark,Electric,Ghost,Ground,Ice,Water,Grass,Fighting,Fairy,Normal,Poison,Bug]

plt.bar(x, y)

plt.title('Pokemons por Tipo')
plt.xlabel('Tipo')
plt.ylabel('Un')
plt.xticks(rotation=45)
plt.show()
