# %% [markdown]
# # Poke Stats - Learning
#
# ## Question:
# ### - Is it posible to predict a pokemon type from stats?

# %% [markdown]
# #### Importing Pandas to read the dataframe ('pokemons').

# %%
import pandas as pd

pokemons = pd.read_csv(r'C:\Users\lluca\Documents\Pokemon.csv')

pokemons.head()
# pokemons.describe()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# Adding a new column 'Count'
pokemons['count'] = 1

# %%
Gen_1 = pokemons.loc[pokemons['Generation'] == 1]
Gen_2 = pokemons.loc[pokemons['Generation'] == 2]
Gen_3 = pokemons.loc[pokemons['Generation'] == 3]
Gen_4 = pokemons.loc[pokemons['Generation'] == 4]
Gen_5 = pokemons.loc[pokemons['Generation'] == 5]
Gen_6 = pokemons.loc[pokemons['Generation'] == 6]

# %% [markdown]
# #### Filtering 'Mega' evolutions

# %%
# How many 'Mega' evolutions?:
print(f"Mega Evolutions: {pokemons.loc[pokemons['Name'].str.contains('Mega')].count()[0]}")
# How many 'Legendaries'?:
print(f"Legendaries: {pokemons.loc[pokemons['Legendary']].count()[0]}")
# Out:
# Mega Evolutions: 49
# Legendaries: 66

# %%
new_df = pokemons
new_df = new_df.loc[~pokemons['Name'].str.contains('Mega')]
new_df = new_df.loc[~new_df['Legendary'] == True]

new_df = new_df.fillna(0)
new_df = new_df.loc[new_df['Type 2'] == 0]

# new_df = new_df.loc[new_df['Type 2'] == '']

# Reseting index
new_df.reset_index(drop = True, inplace = True)
new_df = new_df.drop(['Type 2', 'Legendary'], axis = 1)

gen_1 = new_df.loc[new_df['Generation'] == 1]
gen_2 = new_df.loc[new_df['Generation'] == 2]
gen_3 = new_df.loc[new_df['Generation'] == 3]
gen_4 = new_df.loc[new_df['Generation'] == 4]
gen_5 = new_df.loc[new_df['Generation'] == 5]
gen_6 = new_df.loc[new_df['Generation'] == 6]

gen_3
# Out:
#        #       Name    Type 1  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 129  252    Treecko     Grass    310   40      45       35       65       55
# 130  253    Grovyle     Grass    405   50      65       45       85       65
# 131  254   Sceptile     Grass    530   70      85       65      105       85
# 132  255    Torchic      Fire    310   45      60       40       70       50
# 133  258     Mudkip     Water    310   50      70       50       50       50
# 134  261  Poochyena      Dark    220   35      55       35       30       30
# 135  262  Mightyena      Dark    420   70      90       70       60       60
# 136  263  Zigzagoon    Normal    240   38      30       41       30       41
# 137  264    Linoone    Normal    420   78      70       61       50       61
# 138  265    Wurmple       Bug    195   45      45       35       20       30
# 139  266    Silcoon       Bug    205   50      35       55       25       25
# ...
